# %% [markdown]
# #  Movie Recommender EDA notebook

# %% [markdown]
# author: Ben Sturm <br />
# contact: bwsturm@gmail.com <br />
# date: 6/12/2018

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Data Extraction Steps

# %%
# Reading in the MovieLens 20M ratings dataset
ratings = pd.read_csv('../../data/ml-20m/ratings.csv')

# %%
ratings.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1        2     3.5  1112486027
# 1       1       29     3.5  1112484676
# 2       1       32     3.5  1112484819
# 3       1       47     3.5  1112484727
# 4       1       50     3.5  1112484580

# %%
# Reading in the MovieLens 20M movies dataset
movies = pd.read_csv('../../data/ml-20m/movies.csv')

# %%
movies.tail()
# Out:
#        movieId                          title                    genres
# 27273   131254   Kein Bund für's Leben (2007)                    Comedy
# 27274   131256  Feuer, Eis & Dosenbier (2002)                    Comedy
# 27275   131258             The Pirates (2014)                 Adventure
# 27276   131260            Rentun Ruusu (2001)        (no genres listed)
# 27277   131262               Innocence (2014)  Adventure|Fantasy|Horror

# %%
# Reading in the MovieLens Latest ratings dataset
ratings_latest = pd.read_csv('../../data/ml-latest/ratings.csv')

# %%
ratings_latest.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1      110     1.0  1425941529
# 1       1      147     4.5  1425942435
# 2       1      858     5.0  1425941523
# 3       1     1221     5.0  1425941546
# 4       1     1246     5.0  1425941556

# %%
# Reading in the MovieLens Latest movies dataset
movies_latest = pd.read_csv('../../data/ml-latest/movies.csv')

# %%
movies_latest.tail()
# Out:
#        movieId                       title                 genres
# 45838   176269                      Subdue         Children|Drama
# 45839   176271  Century of Birthing (2011)                  Drama
# 45840   176273             Betrayal (2003)  Action|Drama|Thriller
# 45841   176275     Satan Triumphant (1917)     (no genres listed)
# 45842   176279             Queerama (2017)     (no genres listed)

# %% [markdown]
# ### Data Exploration

# %% [markdown]
# Some questions I have so far:
# * Is it possible to merge the two ratings and movies datasets?
# * Is the data consistent between the MovieLens 20M and the MovieLens Latest such that userIds correspond to the same user?

# %%
ratings.describe()
# Out:
#              userId       movieId        rating     timestamp
# count  2.000026e+07  2.000026e+07  2.000026e+07  2.000026e+07
# mean   6.904587e+04  9.041567e+03  3.525529e+00  1.100918e+09
# std    4.003863e+04  1.978948e+04  1.051989e+00  1.621694e+08
# min    1.000000e+00  1.000000e+00  5.000000e-01  7.896520e+08
# 25%    3.439500e+04  9.020000e+02  3.000000e+00  9.667977e+08
# 50%    6.914100e+04  2.167000e+03  3.500000e+00  1.103556e+09
# 75%    1.036370e+05  4.770000e+03  4.000000e+00  1.225642e+09
# max    1.384930e+05  1.312620e+05  5.000000e+00  1.427784e+09

# %% [markdown]
# Now examining if userId=1 is possibly the same user between the two ratings DataFrames

# %%
ratings[ratings['userId']==1]
# Out:
#      userId  movieId  rating   timestamp
# 0         1        2     3.5  1112486027
# 1         1       29     3.5  1112484676
# 2         1       32     3.5  1112484819
# 3         1       47     3.5  1112484727
# 4         1       50     3.5  1112484580
# 5         1      112     3.5  1094785740
# 6         1      151     4.0  1094785734
# 7         1      223     4.0  1112485573
# 8         1      253     4.0  1112484940
# 9         1      260     4.0  1112484826
# 10        1      293     4.0  1112484703
# 11        1      296     4.0  1112484767
# 12        1      318     4.0  1112484798
# 13        1      337     3.5  1094785709
# 14        1      367     3.5  1112485980
# 15        1      541     4.0  1112484603
# 16        1      589     3.5  1112485557
# 17        1      593     3.5  1112484661
# 18        1      653     3.0  1094785691
# 19        1      919     3.5  1094785621
# 20        1      924     3.5  1094785598
# 21        1     1009     3.5  1112486013
# 22        1     1036     4.0  1112485480
# 23        1     1079     4.0  1094785665
# 24        1     1080     3.5  1112485375
# 25        1     1089     3.5  1112484669
# 26        1     1090     4.0  1112485453
# 27        1     1097     4.0  1112485701
# 28        1     1136     3.5  1112484609
# 29        1     1193     3.5  1112484690
# ..      ...      ...     ...         ...
# 145       1     6242     3.5  1094786004
# 146       1     6333     4.0  1112485502
# 147       1     6502     3.5  1094786048
# 148       1     6539     4.0  1112485508
# 149       1     6754     4.0  1112485984
# 150       1     6755     3.5  1094786067
# 151       1     6774     4.0  1112485786
# 152       1     6807     3.5  1112484686
# 153       1     6834     3.5  1112486060
# 154       1     6888     3.0  1112486127
# 155       1     7001     3.5  1094786101
# 156       1     7045     3.5  1112485834
# 157       1     7046     4.0  1112485934
# 158       1     7153     5.0  1112484633
# 159       1     7164     3.5  1112485923
# 160       1     7247     3.5  1112485958
# 161       1     7387     3.5  1094786161
# 162       1     7389     4.0  1112486045
# 163       1     7438     4.0  1112484789
# 164       1     7449     3.5  1112486163
# 165       1     7454     4.0  1112486108
# 166       1     7482     3.0  1112484575
# 167       1     7757     4.0  1112485819
# 168       1     8368     4.0  1112485688
# 169       1     8482     3.5  1112485781
# 170       1     8507     5.0  1094786027
# 171       1     8636     4.5  1112485493
# 172       1     8690     3.5  1112484795
# 173       1     8961     4.0  1112485629
# 174       1    31696     4.0  1112485748
#
# [175 rows x 4 columns]

# %%
ratings_latest[ratings_latest['userId']==1]
# Out:
#     userId  movieId  rating   timestamp
# 0        1      110     1.0  1425941529
# 1        1      147     4.5  1425942435
# 2        1      858     5.0  1425941523
# 3        1     1221     5.0  1425941546
# 4        1     1246     5.0  1425941556
# 5        1     1968     4.0  1425942148
# 6        1     2762     4.5  1425941300
# 7        1     2918     5.0  1425941593
# 8        1     2959     4.0  1425941601
# 9        1     4226     4.0  1425942228
# 10       1     4878     5.0  1425941434
# 11       1     5577     5.0  1425941397
# 12       1    33794     4.0  1425942005
# 13       1    54503     3.5  1425941313
# 14       1    58559     4.0  1425942007
# 15       1    59315     5.0  1425941502
# 16       1    68358     5.0  1425941464
# 17       1    69844     5.0  1425942139
# 18       1    73017     5.0  1425942699
# 19       1    81834     5.0  1425942133
# 20       1    91500     2.5  1425942647
# 21       1    91542     5.0  1425942618
# 22       1    92439     5.0  1425941424
# 23       1    96821     5.0  1425941382
# 24       1    98809     0.5  1425942640
# 25       1    99114     4.0  1425941667
# 26       1   112552     5.0  1425941336

# %%
ratings_latest.shape
# Out:
# (26024289, 4)

# %%
ratings_latest.movieId.sample(10)
# Out:
# 5396608       3959
# 2704545       1127
# 21718841      1258
# 16405685      7458
# 1511883       1680
# 4092617        372
# 10230649      5618
# 16846305    117895
# 1600666       3507
# 6491960      50685
# Name: movieId, dtype: int64

# %%
movies_latest[movies_latest.movieId==98809]
# Out:
#        movieId                                      title  \
# 20146    98809  Hobbit: An Unexpected Journey, The (2012)
#
#                        genres
# 20146  Adventure|Fantasy|IMAX

# %% [markdown]
# Clearly the userId of 1 is not consistent between the two ratings data sets.  Therefore, I don't think it's safe to merge these two datasets.

# %% [markdown]
# Write a function to strip out the Year from the 'title' column in case if I want to filter by year

# %%
def get_releaseYear(row):
    row_len = len(row)
    if row_len < 2:
        return np.nan
    else:
        return row[-1].replace(')','')

# %%
def get_title(row):
    row_len = len(row)
    if row_len < 2:
        return row[0]
    else:
        return '('.join(row[:-1])

# %%
def strip_Year_from_title(df):
    temp = df['title'].str.split('(')
    df['releaseYear'] = temp.apply(get_releaseYear)
    df['title2'] = temp.apply(get_title)
    return df

# %% [markdown]
# Running my code on movies DataFrame

# %%
movies2 = strip_Year_from_title(movies)
movies2.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres releaseYear  \
# 0  Adventure|Animation|Children|Comedy|Fantasy        1995
# 1                   Adventure|Children|Fantasy        1995
# 2                               Comedy|Romance        1995
# 3                         Comedy|Drama|Romance        1995
# 4                                       Comedy        1995
#
#                          title2
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II

# %%
movies2.drop(columns='title',axis=1,inplace=True)
movies2.rename(columns={'title2':'title'},inplace=True)

# %%
movies2 = movies2.reindex(columns=['movieId','title','releaseYear','genres'])

# %%
movies2.head()
# Out:
#    movieId                         title releaseYear  \
# 0        1                    Toy Story         1995
# 1        2                      Jumanji         1995
# 2        3             Grumpier Old Men         1995
# 3        4            Waiting to Exhale         1995
# 4        5  Father of the Bride Part II         1995
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %% [markdown]
# Running my code on movies_latest DataFrame

# %%
movies_latest2 = strip_Year_from_title(movies_latest)
movies_latest2.drop(columns='title',axis=1,inplace=True)
movies_latest2.rename(columns={'title2':'title'},inplace=True)

# %%
movies_latest2 = movies_latest2.reindex(columns=['movieId','title','releaseYear','genres'])

# %%
movies_latest2.head()
# Out:
#    movieId                         title releaseYear  \
# 0        1                    Toy Story         1995
# 1        2                      Jumanji         1995
# 2        3             Grumpier Old Men         1995
# 3        4            Waiting to Exhale         1995
# 4        5  Father of the Bride Part II         1995
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
movies_latest2['releaseYear'].value_counts()
# Out:
# 2014                        1953
# 2015                        1931
# 2013                        1872
# 2012                        1726
# 2011                        1637
# 2009                        1610
# 2016                        1593
# 2010                        1506
# 2008                        1467
# 2007                        1333
# 2006                        1277
# 2005                        1123
# 2004                        1000
# 2002                         906
# 2003                         894
# 2001                         856
# 2000                         819
# 1998                         727
# 1999                         717
# 1997                         684
# 1996                         636
# 1995                         606
# 1994                         559
# 1993                         494
# 2017                         488
# 1988                         466
# 1987                         463
# 1992                         461
# 1989                         444
# 1990                         431
#                             ...
# 1909                           1
# 1989                           1
# 1887                           1
# 1987                           1
# 1984                           1
# 1972                           1
# 1893                           1
# 1978                           1
# 1997                           1
# 1874                           1
# 2009–                          1
# Das Millionenspiel             1
# 1985                           1
# 1948                           1
# 1994                           1
# 1961                           1
# 1963                           1
# Close Relations                1
# 1957                           1
# 1937                           1
# Your Past Is Showing           1
# 1878                           1
# 1949                           1
# 1938                           1
# 1977                           1
# 1967                           1
# 1983                           1
# 2006–2007                      1
# 1929                           1
# Bicicleta, cullera, poma       1
# Name: releaseYear, Length: 191, dtype: int64

# %%
ratings_latest.shape
# Out:
# (26024289, 4)

# %%
movies_latest2.sample(30)
# Out:
#        movieId                                              title releaseYear  \
# 44490   172789                                       Lovey-Dovey         2007
# 28956   130038                                     Little Deaths         2011
# 11040    45512                        Keeping Up with the Steins         2006
# 43878   171463             The Execution of Mary, Queen of Scots         1895
# 41432   165397                                        Cinderella         1899
# 43525   170631                     Is That a Gun in Your Pocket?         2016
# 15544    78980                   Dynamite Girl (Dynamiittityttö)         1944
# 16883    85108               Lakota Woman: Siege at Wounded Knee         1994
# 14842    74097                                           Cabiria         1914
# 16453    82836                               Life of Reilly, The         2006
# 3116      3202  Even Dwarfs Started Small (Auch Zwerge haben k...        1971
# 24823   115897                     Calm at Sea (La Mer à l'aube)         2012
# 27285   124342             Trapped in the Closet: Chapters 13-22         2007
# 29119   130574                                  Something Wicked         2014
# 16985    85689                                             Otaku         1994
# 12063    54614                                  American Pastime         2007
# 27075   123571                      Jim Jefferies: Alcoholocaust         2010
# 30464   134413                                    Roba da ricchi         1987
# 39258   159223                                          The Pack         2016
# 12094    54908                                            Taxi 4         2007
# 24355   113999     Anna: 6-18 (Anna: Ot shesti do vosemnadtsati)         1994
# 40135   161948                                           Tibetana         NaN
# 23219   109800                                  Quebrando o Tabu         2011
# 35334   148288                               Who Am I This Time?         1982
# 27601   125307                                    Kettle of Fish         2006
# 45374   175127                                         Losing It         2006
# 9658     31150                                           Wizards         1977
# 35121   147434                                    Organize isler         2005
# 42345   167756                                      Of Two Minds         2012
# 19520    96501          Little White Lies (Les petits mouchoirs)         2010
#
#                                genres
# 44490                  Comedy|Fantasy
# 28956                          Horror
# 11040                          Comedy
# 43878              (no genres listed)
# 41432  Children|Fantasy|Horror|Sci-Fi
# 43525                          Comedy
# 15544                    Comedy|Crime
# 16883                           Drama
# 14842             Adventure|Drama|War
# 16453                          Comedy
# 3116                     Drama|Horror
# 24823                       Drama|War
# 27285                    Comedy|Crime
# 29119                Mystery|Thriller
# 16985                     Documentary
# 12063                   Drama|Romance
# 27075                          Comedy
# 30464              (no genres listed)
# 39258                 Horror|Thriller
# 12094                   Action|Comedy
# 24355                     Documentary
# 40135              (no genres listed)
# 23219                     Documentary
# 35334                   Drama|Romance
# 27601                  Comedy|Romance
# 45374                           Drama
# 9658     Animation|Fantasy|Sci-Fi|War
# 35121                          Comedy
# 42345                     Documentary
# 19520                    Comedy|Drama

# %%
movies_latest2.movieId.describe()
# Out:
# count     45843.000000
# mean      96578.775626
# std       57216.863469
# min           1.000000
# 25%       49202.500000
# 50%      108799.000000
# 75%      145270.500000
# max      176279.000000
# Name: movieId, dtype: float64

# %% [markdown]
# ### Recommender model

# %% [markdown]
# Now I'm going to set up a very basic collaborative recommender using the Surprise library.

# %%
from surprise import SVD
from surprise import evaluate, print_perf
from surprise import Reader
from surprise import Dataset
from surprise.model_selection import cross_validate

# %% [markdown]
# My dataset is super large, so I'm going to just sample 1M rows from my dataset and run my first model on my downsampled DataFrame

# %%
ratings_latest_1M = ratings_latest.sample(n=1000000,replace=True)
ratings_latest_1M.shape
# Out:
# (1000000, 4)

# %%
ratings_latest_1M.head()
# Out:
#           userId  movieId  rating   timestamp
# 7323622    75499      367     2.0   837262574
# 14056426  146081    54278     4.5  1227494543
# 4542288    46640     1196     5.0  1445536589
# 7170441    73999      245     3.0   993169936
# 16473112  171269      231     2.0  1460148287

# %%
ratings_latest_1M.reset_index(drop=True,inplace=True)

# %%
ratings_latest_1M.head()
# Out:
#    userId  movieId  rating   timestamp
# 0   75499      367     2.0   837262574
# 1  146081    54278     4.5  1227494543
# 2   46640     1196     5.0  1445536589
# 3   73999      245     3.0   993169936
# 4  171269      231     2.0  1460148287

# %%
reader = Reader(rating_scale=(0.5, 5.0))
data = Dataset.load_from_df(ratings_latest_1M[['userId', 'movieId', 'rating']], reader)

# %%
data.split(n_folds=3)

algo = SVD()

perf = evaluate(algo, data, measures=['RMSE', 'MAE'])
print_perf(perf)
# Out:
# /Users/bwsturm/anaconda/lib/python3.6/site-packages/surprise/evaluate.py:66: UserWarning: The evaluate() method is deprecated. Please use model_selection.cross_validate() instead.
#   'model_selection.cross_validate() instead.', UserWarning)
# /Users/bwsturm/anaconda/lib/python3.6/site-packages/surprise/dataset.py:193: UserWarning: Using data.split() or using load_from_folds() without using a CV iterator is now deprecated.
#   UserWarning)
# Evaluating RMSE, MAE of algorithm SVD.
#
# ------------
# Fold 1
# RMSE: 0.9261
# MAE:  0.7141
# ------------
# Fold 2
# RMSE: 0.9273
# MAE:  0.7148
# ------------
# Fold 3
# RMSE: 0.9277
# MAE:  0.7154
# ------------
# ------------
# Mean RMSE: 0.9271
# Mean MAE : 0.7148
# ------------
# ------------
#         Fold 1  Fold 2  Fold 3  Mean
# RMSE    0.9261  0.9273  0.9277  0.9271
# MAE     0.7141  0.7148  0.7154  0.7148

# %%
uid = str(196)  # raw user id (as in the ratings file). They are **strings**!
iid = str(302)  # raw item id (as in the ratings file). They are **strings**!

# get a prediction for specific users and items.
pred = algo.predict(uid, iid, r_ui=None, verbose=True)
# Out:
# user: 196        item: 302        r_ui = None   est = 3.53   {'was_impossible': False}

# %%
from collections import defaultdict

from surprise import SVD
from surprise import Dataset


def get_top_n(predictions, n=10):
    '''Return the top-N recommendation for each user from a set of predictions.

    Args:
        predictions(list of Prediction objects): The list of predictions, as
            returned by the test method of an algorithm.
        n(int): The number of recommendation to output for each user. Default
            is 10.

    Returns:
    A dict where keys are user (raw) ids and values are lists of tuples:
        [(raw item id, rating estimation), ...] of size n.
    '''

    # First map the predictions to each user.
    top_n = defaultdict(list)
    for uid, iid, true_r, est, _ in predictions:
        top_n[uid].append((iid, est))

    # Then sort the predictions for each user and retrieve the k highest ones.
    for uid, user_ratings in top_n.items():
        user_ratings.sort(key=lambda x: x[1], reverse=True)
        top_n[uid] = user_ratings[:n]

    return top_n


# First train an SVD algorithm on the movielens dataset.
data = Dataset.load_builtin('ml-100k')
trainset = data.build_full_trainset()
algo = SVD()
algo.fit(trainset)

# Than predict ratings for all pairs (u, i) that are NOT in the training set.
testset = trainset.build_anti_testset()
predictions = algo.test(testset)

top_n = get_top_n(predictions, n=10)

# Print the recommended items for each user
#for uid, user_ratings in top_n.items():
#    print(uid, [iid for (iid, _) in user_ratings])

# %%
# Now I'd like to train on the 1M datatset with 3-fold cross validation
reader = Reader(rating_scale=(0.5, 5.0))
data = Dataset.load_from_df(ratings_latest_1M[['userId', 'movieId', 'rating']], reader)

# %%
#data.split(n_folds=3)
#algo = SVD()
#perf = evaluate(algo, data, measures=['RMSE', 'MAE'])
#print_perf(perf)

# %%
#trainset = data.build_full_trainset()

# %% [markdown]
# Surprise isn't working very well for a large dataset like I have.  I'm going to now try another library called implicit.

# %%
from scipy.sparse import csr_matrix
import implicit

# %%
# Initialize sparse matrix of ratings
item_user_data = csr_matrix((ratings_latest_1M['rating'].astype(np.double),
                       (ratings_latest_1M['userId'], #row_id
                        ratings_latest_1M['movieId']))) #column_id

#pd.DataFrame(item_user_data.todense()).head()
print(item_user_data)
# Out:
#   (1, 1246)	5.0
#   (4, 3285)	3.0
#   (5, 1225)	4.0
#   (6, 11)	3.0
#   (6, 2565)	4.0
#   (7, 58559)	5.0
#   (8, 585)	2.0
#   (8, 1405)	4.0
#   (8, 1965)	3.0
#   (8, 2919)	3.0
#   (8, 3175)	5.0
#   (8, 3986)	1.0
#   (8, 5033)	1.0
#   (9, 1183)	4.0
#   (9, 4308)	5.0
#   (9, 5013)	3.0
#   (9, 5902)	3.5
#   (11, 110)	3.5
#   (11, 1089)	7.0
#   (11, 6870)	3.5
#   (11, 33437)	3.0
#   (11, 52328)	3.5
#   (11, 58839)	2.0
#   (12, 273)	3.0
#   (12, 290)	5.0
#   :	:
#   (270893, 2716)	5.0
#   (270893, 2717)	4.0
#   (270893, 4148)	4.0
#   (270894, 296)	3.0
#   (270894, 2165)	2.5
#   (270894, 2858)	3.5
#   (270894, 4475)	4.0
#   (270894, 5618)	1.5
#   (270894, 6787)	5.0
#   (270894, 48774)	2.5
#   (270894, 55820)	3.0
#   (270894, 108729)	4.5
#   (270896, 1)	4.5
#   (270896, 153)	2.0
#   (270896, 288)	3.5
#   (270896, 296)	5.0
#   (270896, 300)	3.5
#   (270896, 1089)	5.0
#   (270896, 1580)	3.0
#   (270896, 1777)	3.0
#   (270896, 1968)	4.5
#   (270896, 2706)	2.5
#   (270896, 5952)	5.0
#   (270896, 7438)	5.0
#   (270896, 35836)	3.5

# %%
# initialize a model
model = implicit.als.AlternatingLeastSquares(factors=50)

# train the model on a sparse matrix of item/user/confidence weights
model.fit(item_user_data)
# Out:
# WARNING:root:Intel MKL BLAS detected. Its highly recommend to set the environment variable 'export MKL_NUM_THREADS=1' to disable its internal multithreading
# 100%|██████████| 15.0/15 [00:12<00:00,  1.14it/s]

# %%
# recommend items for a specific user (user_id = 3)
user_items = item_user_data.T
rec = model.recommend(3,user_items)
#recommendations = pd.DataFrame(model.recommend(3, item_user_data), columns=['movieId', 'score'])

# find related items to a specific movie (Jumanji)
#related = pd.DataFrame(model.similar_items(2), columns=['movieId', 'score'])

# %%
movies_latest2['index'] = movies_latest2.index + 1
movies_latest2.head()
# Out:
#    movieId                         title releaseYear  \
# 0        1                    Toy Story         1995
# 1        2                      Jumanji         1995
# 2        3             Grumpier Old Men         1995
# 3        4            Waiting to Exhale         1995
# 4        5  Father of the Bride Part II         1995
#
#                                         genres  index
# 0  Adventure|Animation|Children|Comedy|Fantasy      1
# 1                   Adventure|Children|Fantasy      2
# 2                               Comedy|Romance      3
# 3                         Comedy|Drama|Romance      4
# 4                                       Comedy      5

# %%
#recommendations_with_title = pd.merge(recommendations,movies_latest2,left_on='movieId', right_on='index')
#print(recommendations.columns)
#print(movies_latest2.columns)

# %%
recommendations_with_title

# %%
recommendations

# %%
related

# %%
rec

# %%
# Initialize sparse matrix of ratings using the full dataset
item_user_data = csr_matrix((ratings_latest['rating'].astype(np.double),
                       (ratings_latest['userId'], #row_id
                        ratings_latest['movieId']))) #column_id

#pd.DataFrame(item_user_data.todense()).head()
print(item_user_data)

# %%
# initialize a model
model = implicit.als.AlternatingLeastSquares(factors=50)

# train the model on a sparse matrix of item/user/confidence weights
model.fit(item_user_data)

# %%
# recommend items for a specific user (user_id = 3)
user_items = item_user_data.T
#rec = model.recommend(3,user_items)
recommendations = pd.DataFrame(model.recommend(3, user_items), columns=['movieId', 'score'])

# find related items to a specific movie (Jumanji)
#related = pd.DataFrame(model.similar_items(2), columns=['movieId', 'score'])

# %%
recommendations

# %% [markdown]
# I have a hunch that the model might not be working because some users had just 1 rating.  In order to test this hunch, I'm going to use the 20M dataset.  The readme states that each user in this datatset had at least 20 ratings.

# %%
# Initialize sparse matrix of ratings using the full dataset
item_user_data_20M = csr_matrix((ratings['rating'].astype(np.double),
                       (ratings['userId'], #row_id
                        ratings['movieId']))) #column_id

#pd.DataFrame(item_user_data.todense()).head()
#print(item_user_data)

# %%
# initialize a model
model = implicit.als.AlternatingLeastSquares(factors=50)

# train the model on a sparse matrix of item/user/confidence weights
model.fit(item_user_data_20M)

# %%
# recommend items for a specific user (user_id = 3)
user_items_20M = item_user_data_20M.T
#rec = model.recommend(3,user_items)
recommendations = pd.DataFrame(model.recommend(3, user_items_20M), columns=['movieId', 'score'])

# find related items to a specific movie (Jumanji)
#related = pd.DataFrame(model.similar_items(2), columns=['movieId', 'score'])

# %%
movies2['index'] = movies2.index + 1
movies2.head()

# %%
recommendations

# %%
recommendations_with_title = pd.merge(recommendations,movies2,left_on='movieId',right_on='index')

# %%
recommendations_with_title

# %%
movies2[movies2.movieId==34962]
